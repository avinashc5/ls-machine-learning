# %%
from ultralytics import YOLO
import os
from IPython.display import display, Image
from IPython import display
display.clear_output()

# %%
# !yolo task=detect mode=train model=yolo8m.pt data='body-parts-cq3al' epochs=20 imgsz=640
# Out:
# Traceback (most recent call last):
#   File "/home/avinashc/.local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#              ^^^^^^^^^^^^
#   File "/home/avinashc/.local/lib/python3.12/site-packages/ultralytics/cfg/__init__.py", line 681, in entrypoint
#     model = YOLO(model, task=task)
#             ^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/avinashc/.local/lib/python3.12/site-packages/ultralytics/models/yolo/model.py", line 23, in __init__
#     super().__init__(model=model, task=task, verbose=verbose)
#   File "/home/avinashc/.local/lib/python3.12/site-packages/ultralytics/engine/model.py", line 149, in __init__
#     self._load(model, task=task)
#   File "/home/avinashc/.local/lib/python3.12/site-packages/ultralytics/engine/model.py", line 230, in _load
#     self.model, self.ckpt = attempt_load_one_weight(weights)
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/avinashc/.local/lib/python3.12/site-packages/ultralytics/nn/tasks.py", line 855, in attempt_load_one_weight
#     ckpt, weight = torch_safe_load(weight)  # load ckpt
#                    ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/avinashc/.local/lib/python3.12/site-packages/ultralytics/nn/tasks.py", line 781, in torch_safe_load
#     ckpt = torch.load(file, map_location="cpu")
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/avinashc/.local/lib/python3.12/site-packages/torch/serialization.py", line 997, in load
#     with _open_file_like(f, 'rb') as opened_file:
#          ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/avinashc/.local/lib/python3.12/site-packages/torch/serialization.py", line 444, in _open_file_like
#     return _open_file(name_or_buffer, mode)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/avinashc/.local/lib/python3.12/site-packages/torch/serialization.py", line 425, in __init__
#     super().__init__(open(name, mode))
#                      ^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: 'yolo8m.pt'

# %%
model = YOLO('yolov8n.pt')
model = YOLO('runs/detect/train/weights/best.pt')

# Validate the model
metrics = model.val()  # no arguments needed, dataset and settings remembered
metrics.box.map  # map50-95
metrics.box.map50  # map50
metrics.box.map75  # map75
metrics.box.maps  # a list contains map50-95 of each category
# Out:
# Ultralytics YOLOv8.2.55 🚀 Python-3.12.3 torch-2.3.1+cu121 CPU (AMD Ryzen 7 5825U with Radeon Graphics)
# YOLOv8n summary (fused): 168 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
# val: Scanning /home/avinashc/Documents/ls/machine_learning/yolo/datasets/coco8/labels/val.cache... 4 images, 0 backgrounds, 0 corrupt: 100%|██████████| 4/4 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  1.19it/s]
#                    all          4         17      0.599      0.898      0.888      0.618
#                 person          3         10      0.647        0.5       0.52       0.29
#                    dog          1          1      0.315          1      0.995      0.597
#                  horse          1          2      0.689          1      0.995      0.598
#               elephant          1          2      0.629      0.886      0.828      0.332
#               umbrella          1          1      0.539          1      0.995      0.995
#           potted plant          1          1      0.774          1      0.995      0.895
# Speed: 2.8ms preprocess, 201.2ms inference, 0.0ms loss, 1.3ms postprocess per image
# Results saved to runs/detect/val
# array([    0.28989,     0.61799,     0.61799,     0.61799,     0.61799,     0.61799,     0.61799,     0.61799,     0.61799,     0.61799,     0.61799,     0.61799,     0.61799,     0.61799,     0.61799,     0.61799,       0.597,     0.59809,     0.61799,     0.61799,     0.33246,     0.61799,     0.61799,     0.61799,
#            0.61799,       0.995,     0.61799,     0.61799,     0.61799,     0.61799,     0.61799,     0.61799,     0.61799,     0.61799,     0.61799,     0.61799,     0.61799,     0.61799,     0.61799,     0.61799,     0.61799,     0.61799,     0.61799,     0.61799,     0.61799,     0.61799,     0.61799,     0.61799,
#            0.61799,     0.61799,     0.61799,     0.61799,     0.61799,     0.61799,     0.61799,     0.61799,     0.61799,     0.61799,      0.8955,     0.61799,     0.61799,     0.61799,     0.61799,     0.61799,     0.61799,     0.61799,     0.61799,     0.61799,     0.61799,     0.61799,     0.61799,     0.61799,
#            0.61799,     0.61799,     0.61799,     0.61799,     0.61799,     0.61799,     0.61799,     0.61799])

# %%
# Load a pretrained YOLOv8n model
model = YOLO("yolov8n.pt")

# Define path to directory containing images and videos for inference
source = "test"

# Run inference on the source
results = model(source, stream=True)  # generator of Results objects

# %%
Image.open('runs/detect/train/confusion_matrix.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=3000x2250>
